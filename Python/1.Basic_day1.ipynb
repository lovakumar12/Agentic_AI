# %% [markdown]
# ### Day-1

# %% [markdown]
# ## Setup environment
#
# step-0
# open anaconda powershell
#
#
#
# step-1   (base) PS C:\Users> cd DELL
#
# step-2  (base) PS C:\Users\DELL> cd onedrive
#
# step-3  (base) PS C:\Users\DELL\onedrive> pwd
#
# Path
# ----
# C:\Users\DELL\onedrive
#
#
# step-4 (base) PS C:\Users\DELL\onedrive> cd desktop
#
#
# step-5 (base) PS C:\Users\DELL\onedrive\desktop> mkdir sabikds
#
#
#     Directory: C:\Users\DELL\onedrive\desktop
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----        20-08-2024     15:53                sabikds
#
#
# step-6 (base) PS C:\Users\DELL\onedrive\desktop> cd sabikds
#
#
# step-7 (base) PS C:\Users\DELL\onedrive\desktop\sabikds> code .
#
#
# (base) PS C:\Users\DELL\onedrive\desktop\sabikds>

# %% [markdown]
# (base) PS C:\Users\DELL\OneDrive\Desktop\sabikds> conda activate sabikds
#
# (sabikds) PS C:\Users\DELL\OneDrive\Desktop\sabikds>

# %% [markdown]
# ## How do we communicate?

# %% [markdown]
# we are communicating from person to another person by using Grammar(syntax)
#
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language. In simpler terms, syntax is about the correct arrangement of words and symbols in a code
#
#
# every language has associated with grammar
#
# example: I am Laxman (gives proper meaning) ✅
#
# am laxman I (not given any proper meaning) ❌

# %% [markdown]
# ### How do human communicate with machine?

# %% [markdown]
# The machine knows only binary language like (zeros and one's) 0,1,0,1,1,0,0⏰
#
# but Human communicate person to another by using Grammatical language
#
# so To communcate with human to machine or machine to human, we need one programming language
#
# there are several programming languages are existed such as C,C++,JAVA, PYTHON

# %% [markdown]
# ## Why do we need programming?

# %% [markdown]
# Suppose we are doing some mathematical operations like mulitiplications, additions and subtractions....
#
# we can calculate manually very easily 3 * 5=15 but incase of 221*224=? to calcuate this values it take sometime. if we use programming lanuage for calculating 221 * 224 , it takes only few seconds

# %% [markdown]
# ## Application of programming Languages?(Python)

# %% [markdown]
# It can apply on
#
# ## Web development:
#
# Python is widely used for web development, and many popular web frameworks, such as Django, Flask, and Pyramid, are written in Python. These frameworks provide a powerful and flexible way to build web applications, from small-scale websites to large-scale enterprise applications
#
# ## Data science and analytics:
#
#  Python has become one of the most popular programming languages for data science and machine learning. Popular libraries, such as NumPy, Pandas, Matplotlib, and Scikit-learn, are used for data analysis, visualization, and machine learning which makes Python a high demand language for data science.
#
# ## Automation and scripting:
#
#  Python is used extensively for automation tasks, such as scripting, testing, and deployment. It provides a simple and efficient way to automate repetitive tasks and to integrate systems and services
#
# ## Game development:
#
#  Python can be used to develop games using libraries such as Pygame, which provides a set of tools for game development, including graphics, sound, and input handling
#
# ## DevOps:
#
#  Python is used extensively in the DevOps community for tasks such as automation, infrastructure management, and deployment. Tools such as Ansible and SaltStack are written in Python

# %% [markdown]
# ## History of Python?

# %% [markdown]
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0
#
# Rossum used to love watching comedy movies from late seventies
#
# He needed a short , unique and slightly mystrerious name of his language

# %% [markdown]
# ### Why do we learn Python?

# %% [markdown]
# ## Easy to learn and use:
#  Python is easy to learn and use, even for beginners. Its syntax is clean and simple, almost like writing in English
#
# ## Object-oriented:
#  Python is an object-oriented programming language, which means it has features like code reusability and modularity. It supports features such as abstraction, encapsulation, inheritance, and polymorphism
#
# ## Interpreted:
#  Python is an interpreted language, which means the code is executed line by line. This makes the development process faster and more efficient as it eliminates the need for a compilation step and if some error occurs it will not wait for the whole code to compile it will throw error at that particular line itself
#
# ## High-level language:
#  Python is a high-level language, which means it abstracts away many of the low-level details of computer hardware. This allows developers to focus on the problem they are trying to solve rather than the implementation details
#
# ## Free and Open Source:
#  The Python programming language is free and open-source, which means it can be used on any operating system free of charge.Python along with its libraries and documentation can be downloaded from Python's official website.In addition to downloading, you can also create and distribute your own modules or libraries
#
# ## Databases Support:
#  Python provides robust support for working with databases through its standard library and third-party packages like SQLite3, MySQL Connector, PostgreSQL, SQLAlchemy, MongoDB. Python also supports Object-Relational Mapping (ORM) frameworks, such as Django ORM and SQLAlchemy, which provide an abstraction layer on top of databases, making it easier to work with data in object-oriented Python code

# %% [markdown]
# # Where do we practice coding?

# %% [markdown]
# IDE is An Integrated Development Environment (IDE)
#
# IDE is a software application that provides programmers with a comprehensive set of tools and features to write, debug, and test their code in a single interface(place).
#
# IDEs often include a text (notebook), editor(command line), a debugger, a compiler, and other features like autocomplete, syntax highlighting, and code formatting.
#
# IDEs are designed to make the coding process more efficient and productive by providing all the necessary tools and features in one place, which can save time and effort for developers. IDEs are commonly used for programming languages like Python, Java, C++, and many more.
#
# Few examples of IDE:
#
# Jupyter
#
# Google Colab
#
# IDLE
#
# VScode
#
# PyCharm
#
# Spyder
#
# Visual Studio Code (VSCode):
#
# We'll be using Google Colab for our journey

# %% [markdown]
# # Environment settings
#
# open your anaconda prompt
#
# dir
#
# cd desktop
#
# mkdir vspratice
#
# cd vspratice
#
# code .
#
# conda create -p venv python==3.8 -y
#
# conda activate venv/
#
# Virtual environment(conda create -p venv pyhton==3.8 -y
#
# step-2 conda activate  venv/
#
#
# 1)open new terminal in vs code –powershell
#
# 2)Enter   python --version  ( to check the python installed in your system if not just download it)
#
# 3)enter   python -m venv <path of folder> \venv
#
# 4)ctrl+shift +p (to open the python interpreter)
#
# Then select (python: select interpreter Enter interpreter pathfind select venv  select scripts  select python

# %% [markdown]
# ## what is Data?

# %% [markdown]
# collection of information gathered by observations, measurements, research or analysis. They may consist of facts, numbers, names, figures or even description of things.

# %% [markdown]
# ## How to store Data?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Python builtin data types
#
# https://docs.python.org/3/library/stdtypes.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Different data types we will encounter in Python
# ## Numeric -
#  Numeric variables take values which are numbers like 9, 3.14, 0, Inf
#
# # String -
#  String variables are used to store textual information
# # Boolean -
#  Boolean variables have two modes either True or False. A definite judge of statements!
# # Datetime -
#  These variables are used to store date and time values such as 2020-08-01 12:23:54

# %% [markdown]
# ## why do we need variables?
# A variable with a fixed name can store information of nature like numeric, textual, boolean etc,( data/value can be stored for temporary stroage space)

# %% [markdown]
# # Operators in Varibales?
# Arithmetic operators
#
# Assignment operators
#
# Comparison operators
#
# Logical operators
#
# Identity operators
#
# Membership operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Addition
2+3
# Out:
# 5

# %%
5+249
# Out:
# 254

# %%
# Subtraction
5-2
# Out:
# 3

# %%
# Multiplication
2*3
# Out:
# 6

# %%
# Division
3/2
# Out:
# 1.5

# %%
25/5
# Out:
# 5.0

# %%
# Floor Division
print(3//2)
print(7//2)
print(25//5)
# Out:
# 1
# 3
# 5

# %%
25//5
# Out:
# 5

# %% [markdown]
# # Waittt! Should not it be 0.75??
# The reason we get this result is because we are using "floor" division. The // operator (two forward slashes) is the mathematical equivalent of doing [0.75] which returns the greatest integer less than or equal to 0.75

# %%
print("divison",3/4)
print("floor divison",3//4)

print("divison",4/5)

print("floor divison",4//5)
# Out:
# divison 0.75
# floor divison 0
# divison 0.8
# floor divison 0

# %%
1000%10
# Out:
# 0

# %%
# Modulo operator
y=5
x=3

z = y%x       # Modulus is denoted by % sign
print(z)
# Out:
# 2

# %%
# Modulus
7%6
# Out:
# 1

# %%
12%8
# Out:
# 4

# %%
100%10
# Out:
# 0

# %%
10%100
# Out:
# 10

# %%
# Out:
# 0

# %%
3%4
# Out:
# 3

# %%
12%8
# Out:
# 4

# %%
8%12
# Out:
# 8

# %%
# Exponentiation
print(2**2)
print(2**3)
# Out:
# 4
# 8

# %% [markdown]
# # PEMDAS is followed by python bodmas rule is not followed by python

# %%
# Order of Operations followed in Python
2 + 10 * 10 + 3
# Out:
# 105

# %%
25/(5*20)+(132-122)+52
# Out:
# 62.25

# %%
25/5*20+(132-122)+52
# Out:
# 162.0

# %%
25/5*20+132-122+52
# Out:
# 162.0

# %%
5+21//(12*3)
# Out:
# 5

# %%
25+23-1001%10120//(125-25)
# Out:
# 38

# %% [markdown]
# Basic Arithmetic operations we can do on x and y. Later we will be doing operations on thousands of such numbers in one go!

# %%
x=5

# %%
y=6.4

# %%
x+y
# Out:
# 11.4

# %%
x-y
# Out:
# -1.4000000000000004

# %%
x*y
# Out:
# 32.0

# %%
# Addition
z = x+y

print(z)
# Out:
# 11.4

# %%
print(id(z))
# Out:
# 1504654686672

# %%
# Printing the memory address the variable z occupies
print(oct(id(z)))
# Out:
# 0o25712432074720

# %%
# Division
z = x/y

print(z) # Print the variable z
type(z)  # Get the data type of variable z
# Out:
# 0.78125
# float

# %%
type(x)     # type is keyword getting data type of variable
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
a=sabik
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 zx=sabik
#
# NameError: name 'sabik' is not defined

# %%
a="sabik"

# %%
type(a)
# Out:
# str

# %%
b="6"

# %%
type(b)
# Out:
# str

# %%
c='8'

type(c)
# Out:
# str

# %%
print(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(g)
#
# NameError: name 'g' is not defined

# %%
type(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 type(e)
#
# NameError: name 'e' is not defined

# %% [markdown]
# VARIABLES are entities which help us store information and retrieve it later.

# %% [markdown]
# A variable with a fixed name can store information of nature like numeric, textual, boolean etc.
#
# A Python variable is a reserved memory location to store values.
#
# In other words, a variable in a python program gives data to the computer for processing.
#
# The type of data contained in a variable can be changed at user's will.

# %%
# You can store numbers in variables.
# The standard rule is you write the variable name followed by = sign and the value it will take

5
# Out:
# 5

# %% [markdown]
# Rules for naming a variable in Python
#
# Variables names must start with a letter or an underscore ,like _ product , product_
#
# Examples a=5 , _b=7
#
# Variable names cannot be start with NUMBERS example 1b=9
#
# The remainder of your variable name may consist of letters, numbers and underscores examples B1_=10
#
# spacy1, pyThon,machine_learning are some valid variable names
#
# Variablenames cannot be used with python inbuilt keywords like str, type,int,float
#
# Names are case sensitive. means capital letters are different from small letters
#
# case_sensitive, CASE_SENSITIVE, and Case_Sensitive are each a different variable.

# %%
a=6
a     #Variables names must start with a letter or an underscore
# Out:
# 6

# %%
_a=9                       #Variables names must start with a letter or an underscore
_a
# Out:
# 9

# %%
va7_=8                           #variable name may consist of letters, numbers and underscores
va7_
# Out:
# 8

# %%
7a=10                            #Variable names cannot be start with NUMBERS
7a
# Out:
#   Cell In[39], line 1
#     7a=10                            #Variable names cannot be start with NUMBERS
#      ^
# SyntaxError: invalid syntax

# %%
 _bc=143                # variables Names in pyhton was case sensitive which  means capital letters are different from small letters

_BC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 _bc=143                # variables Names in pyhton was case sensitive which  means capital letters are different from small letters
# ----> 3 _BC
#
# NameError: name '_BC' is not defined

# %%
BD=111

print(bd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 BD=111
# ----> 3 print(bd)
#
# NameError: name 'bd' is not defined

# %%
a_b=7

a_b
# Out:
# 7

# %%
import keyword
print(keyword.kwlist)

len(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
True = 5      #  variables names can't be assign to  Keywords
True
# Out:
#   Cell In[44], line 1
#     True = 5      #  variables names can't be assign to  Keywords
#     ^
# SyntaxError: cannot assign to True

# %%
true=5
print(true)
# Out:
# 5

# %% [markdown]
# # Assignment operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x="Orange"
y="Banana"

z="Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
#Unpack a list:

fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Boolean Variables

# %% [markdown]
# A Boolean variable only takes two values either True or False. It is used for comparisons

# %% [markdown]
# # 3.Comparison Operators
#
# These operators will allow us to compare variables and output a Boolean value (True or False).
#
# If you have any sort of background in Math, these operators should be very straight forward.
#
# First we'll present a table of the comparison operators and then work through some examples:
# In the table below, a=3 and b=4.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Set object to be a boolean
abc= False
type(abc)
# Out:
# bool

# %%
#Calling variable abc
abc
# Out:
# False

# %%
#
a=7

b=4

a>b
# Out:
# True

# %% [markdown]
# # Equal

# %%
2 == 3
# Out:
# False

# %%
2==0
# Out:
# False

# %% [markdown]
# > Note that == is a comparison operator, while = is an assignment operator.

# %% [markdown]
# Not equal

# %%
2!=0
# Out:
# True

# %% [markdown]
# 2!=2

# %% [markdown]
# Greater than

# %%
a=3
b=2
a<b
# Out:
# False

# %%
a == 3
# Out:
# True

# %%
b > 4
# Out:
# False

# %% [markdown]
# Less than

# %%
10 < 45
# Out:
# True

# %%
4 < 2
# Out:
# False

# %% [markdown]
# Greater than or equal to

# %%
3 >=2
# Out:
# True

# %%
4 >= 4
# Out:
# True

# %% [markdown]
# Less than or equal to

# %%
3 <= 0
# Out:
# False

# %%
1 <= 2
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # and

# %%
x=50
print(x)
# Out:
# 50

# %%
x < 6 and x < 10   #  False  and False = False
# Out:
# False

# %%
x > 6 and x < 10  #  True and False = False
# Out:
# False

# %%
x > 6 and x > 10  #  True and True = True
# Out:
# True

# %% [markdown]
# # or

# %%
x > 6 or x >10   # True or True = True
# Out:
# True

# %%
x > 6 or x < 10 # True or False  = True
# Out:
# True

# %%
x < 6 or x < 10  # False or False = False
# Out:
# False

# %% [markdown]
# # not

# %%
not(x < 6 or x < 10)
# Out:
# True

# %%
not(x > 6 and x > 10)
# Out:
# False

# %% [markdown]
# ### `Membership Operators`
#
# ### Membership operators are used to test if a sequence is presented in an object:

# %%
y=[3,4,5,7,7,343,45676,5,"ravi",4+6j,0.5]

# %%
print(x in y)
# Out:
# False

# %%
print(4 in y)
# Out:
# True

# %%
print(x not in y)
# Out:
# True

# %% [markdown]
# ## input/output operatiors

# %%
name = input("Enter your name: ")
age_text = input("Enter your age: ")
age = int(age_text)
print("Hello,", name)
print("Next year you will be", age + 1)

# %%
width = float(input("Enter width: "))
height = float(input("Enter height: "))
print(width * height)

x = float(input("Enter first number: "))
y = float(input("Enter second number: "))
print(x + y, x - y, x * y)

# %% [markdown]
# ## Here are clear examples of commenting in Python with code. I’ll include all types of comments:
# ✔ Single-line comments
#
# ✔ Multi-line comments
#
# ✔ Inline comments
#
# ✔ Docstrings (function/class documentation)

# %% [markdown]
# ### ✅ 1. Single-Line Comments (#)

# %%
# This is a single-line comment
x = 10  # Assigning value 10 to x

# Printing the value
print(x)

# %% [markdown]
# ### ✅ 2. Multi-Line Comments (Using Triple Quotes)

# %%
"""
This is a multi-line comment.
You can write descriptions here.
This will be ignored by Python if not assigned to any variable.
"""
print("Hello")

# %% [markdown]
# ### ✅ 3. Inline Comments

# %%
a = 5   # first number
b = 7   # second number

result = a + b  # adding two numbers
print(result)
# Out:
# 12

# %% [markdown]
# ### ✅ 4. Commenting Inside Code Block

# %%
for i in range(5):
    # Loop runs 5 times
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### ✅ 5. Docstrings — Used for Functions / Classes
# ✔ These are NOT comments but used to document code.
#
# ✔ Very important for clean coding.

# %%
def add(a, b):
    """
    This function takes two numbers and returns their sum.
    Parameters:
        a (int or float): First number
        b (int or float): Second number
    Returns:
        int or float: Sum of a and b
    """
    return a + b

print(add(3, 4))
# Out:
# 7
